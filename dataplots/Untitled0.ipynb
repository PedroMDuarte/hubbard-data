# %%
f1 = np.loadtxt('../QMCdatacopy/U02/saf6l54u2T0.370dt0.05.dat', skiprows=1 )
f2 = np.loadtxt('../QMCdatacopy/U02/saf6u2T0.37dt0.05.dat', skiprows=7)


print f1.shape
print f2.shape
# Out:
# (120, 7)
# (114, 7)

# %%
fig, ax = plt.subplots(6,1, sharex=True)

print ax

for i in range(6):
    ax[i].plot( f1[:,0], f1[:,1+i])
    ax[i].plot( f2[:,0], f2[:,1+i])
